# %% [markdown]
# # Transaction Anomaly Detection Analysis
#
# This notebook analyzes the transaction dataset to understand:
# 1. Data structure and quality
# 2. Current CTG (Customer Transaction Graph) approach
# 3. Potential anomalies and patterns
# 4. Recommendations for improvement

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# Set plotting style
plt.style.use('default')
sns.set_palette("husl")

# %% [markdown]
# ## 1. Load and Explore Data

# %%
# Load the dataset
df = pd.read_csv('../data/customer_trust_dataset_full.csv')

print(f"Dataset shape: {df.shape}")
print(f"Memory usage: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")

print("\nColumn names and types:")
print(df.dtypes)

# Display first few rows
print("\nFirst 5 rows:")
df.head()
# Out:
# Dataset shape: (4000, 15)
# Memory usage: 2.36 MB
#
# Column names and types:
# Unnamed: 0                         int64
# order_id                           int64
# order_captured_at                 object
# order_total_spent                float64
# browser_ip                        object
# email                             object
# order_status                      object
# shipping_zip                       int64
# credit_card_bin                  float64
# ua_browser                        object
# user_agent                        object
# shipping_address1                 object
# formatted_shipping_address        object
# normalized_full_shipping_name     object
# cookie                            object
# dtype: object
#
# First 5 rows:
#    Unnamed: 0    order_id    order_captured_at  order_total_spent  \
# 0           1  2993832484  2020-09-15 14:58:09             125.00
# 1           2  2993898247  2020-09-15 15:28:57             125.00
# 2           3  2993830110  2020-09-15 14:57:00             125.00
# 3           4  2993731820  2020-09-15 14:06:45             135.47
# 4           5  2993736863  2020-09-15 14:08:57             125.00
#
#           browser_ip                          email order_status  \
# 0   34.40.254.455/32            jahff5667@gmail.com     captured
# 1    23.25.22.233/32  morlancranforc02250@gmail.com     captured
# 2  55.407.475.475/32          h2429007025@gmail.com     captured
# 3  400.44.437.475/32      williameb204903@gmail.com     declined
# 4  402.237.30.457/32          timmy0627ok@gmail.com     captured
#
#    shipping_zip  credit_card_bin ua_browser user_agent  \
# 0          3049         433668.0        NaN        NaN
# 1          7007         370021.0        NaN        NaN
# 2          3049         544243.0        NaN        NaN
# 3         20780         379736.0      Other        NaN
# 4         29720         379811.0        NaN        NaN
#
#             shipping_address1            formatted_shipping_address  \
# 0     98DT 27B Clrnton Dr ybv                                   NaN
# 1      RJBJ 276 Zrlson Street                                   NaN
# 2              27B Clrnton Dr                                   NaN
# 3   30 Eln Pl., Bpbrtnent #4B  30 Eln Pl Bpt 4b, Rye, NY, 20780, US
# 4  NXK 207B Old Churchnbns Rd                                   NaN
#
#   normalized_full_shipping_name cookie
# 0                   ppprq ddvid    NaN
# 1               morldn crdnford    NaN
# 2                    hzl zilong    NaN
# 3           bridn john willidms    NaN
# 4                   pmflw iwdnd    NaN

# %%
# Basic statistics
print("Basic statistics for numerical columns:")
df.describe()

# Missing values
print("\nMissing values per column:")
missing_data = df.isnull().sum()
print(missing_data[missing_data > 0])

# Order status distribution
print("\nOrder status distribution:")
print(df['order_status'].value_counts())

# Unique values in key columns
print("\nUnique values in key columns:")
print(f"Unique emails: {df['email'].nunique()}")
print(f"Unique IPs: {df['browser_ip'].nunique()}")
print(f"Unique shipping addresses: {df['shipping_address1'].nunique()}")
print(f"Unique order IDs: {df['order_id'].nunique()}")
# Out:
# Basic statistics for numerical columns:
#
# Missing values per column:
# credit_card_bin                 95
# ua_browser                    1936
# user_agent                    2815
# formatted_shipping_address    3048
# cookie                        3597
# dtype: int64
#
# Order status distribution:
# order_status
# captured     1934
# declined     1508
# cancelled     287
# approved      271
# Name: count, dtype: int64
#
# Unique values in key columns:
# Unique emails: 1642
# Unique IPs: 2685
# Unique shipping addresses: 1353
# Unique order IDs: 4000

# %% [markdown]
# ## 2. Analyze Transaction Patterns

# %%
# Convert timestamp
df['order_captured_at'] = pd.to_datetime(df['order_captured_at'])

# Amount analysis
print("Transaction amount analysis:")
print(f"Min amount: ${df['order_total_spent'].min()}")
print(f"Max amount: ${df['order_total_spent'].max()}")
print(f"Mean amount: ${df['order_total_spent'].mean():.2f}")
print(f"Median amount: ${df['order_total_spent'].median():.2f}")
print(f"Std amount: ${df['order_total_spent'].std():.2f}")

# Time analysis
print(f"\nTime range: {df['order_captured_at'].min()} to {df['order_captured_at'].max()}")
print(f"Duration: {(df['order_captured_at'].max() - df['order_captured_at'].min()).total_seconds() / 3600:.1f} hours")
# Out:
# Transaction amount analysis:
# Min amount: $98.8
# Max amount: $538.55
# Mean amount: $126.73
# Median amount: $125.00
# Std amount: $10.86
#
# Time range: 2020-09-15 14:01:27 to 2020-09-16 04:06:56
# Duration: 14.1 hours

# %%
# Duplicate analysis
print("Duplicate analysis:")
print(f"Duplicate emails: {df['email'].duplicated().sum()}")
print(f"Duplicate IPs: {df['browser_ip'].duplicated().sum()}")
print(f"Duplicate addresses: {df['shipping_address1'].duplicated().sum()}")

# Suspicious patterns
print("\nSuspicious patterns:")

# Same email, different IPs
email_ip_groups = df.groupby('email')['browser_ip'].nunique()
suspicious_emails = email_ip_groups[email_ip_groups > 1]
print(f"Emails with multiple IPs: {len(suspicious_emails)}")

# Same IP, different emails
ip_email_groups = df.groupby('browser_ip')['email'].nunique()
suspicious_ips = ip_email_groups[ip_email_groups > 1]
print(f"IPs with multiple emails: {len(suspicious_ips)}")

# Same address, different emails
addr_email_groups = df.groupby('shipping_address1')['email'].nunique()
suspicious_addresses = addr_email_groups[addr_email_groups > 1]
print(f"Addresses with multiple emails: {len(suspicious_addresses)}")
# Out:
# Duplicate analysis:
# Duplicate emails: 2358
# Duplicate IPs: 1315
# Duplicate addresses: 2647
#
# Suspicious patterns:
# Emails with multiple IPs: 637
# IPs with multiple emails: 327
# Addresses with multiple emails: 87

# %% [markdown]
# ## 3. Identify Anomaly Indicators

# %%
# Amount-based anomalies
amount_q99 = df['order_total_spent'].quantile(0.99)
amount_q01 = df['order_total_spent'].quantile(0.01)
high_amount = df[df['order_total_spent'] > amount_q99]
low_amount = df[df['order_total_spent'] < amount_q01]

print(f"High amount transactions (>99th percentile): {len(high_amount)}")
print(f"Low amount transactions (<1st percentile): {len(low_amount)}")
print(f"99th percentile amount: ${amount_q99:.2f}")
print(f"1st percentile amount: ${amount_q01:.2f}")

# Time-based anomalies
df['hour'] = df['order_captured_at'].dt.hour
df['minute'] = df['order_captured_at'].dt.minute

# Transactions at unusual hours
unusual_hours = df[(df['hour'] < 6) | (df['hour'] > 22)]
print(f"\nTransactions at unusual hours (6am-10pm): {len(unusual_hours)}")

# Rapid successive transactions
df_sorted = df.sort_values(['email', 'order_captured_at'])
df_sorted['time_diff'] = df_sorted.groupby('email')['order_captured_at'].diff()
rapid_transactions = df_sorted[df_sorted['time_diff'] < pd.Timedelta(minutes=5)]
print(f"Rapid successive transactions (<5 min): {len(rapid_transactions)}")
# Out:
# High amount transactions (>99th percentile): 33
# Low amount transactions (<1st percentile): 39
# 99th percentile amount: $137.44
# 1st percentile amount: $115.00
#
# Transactions at unusual hours (6am-10pm): 62
# Rapid successive transactions (<5 min): 1624

# %%
# Geographic anomalies
ip_zip_groups = df.groupby('browser_ip')['shipping_zip'].nunique()
geo_anomalies = ip_zip_groups[ip_zip_groups > 1]
print(f"IPs with multiple shipping locations: {len(geo_anomalies)}")

# Email pattern anomalies
suspicious_emails = df[df['email'].str.contains(r'[0-9]{8,}', regex=True)]
print(f"Emails with 8+ consecutive digits: {len(suspicious_emails)}")

# Show some examples
print("\nExamples of suspicious emails:")
print(suspicious_emails[['email', 'order_status', 'order_total_spent']].head())
# Out:
# IPs with multiple shipping locations: 82
# Emails with 8+ consecutive digits: 1000
#
# Examples of suspicious emails:
#                          email order_status  order_total_spent
# 2        h2429007025@gmail.com     captured              125.0
# 8             770722324@bb.com     declined              125.0
# 14  tyujk49065343@alexytop.com     captured              125.0
# 15           2907742723@bb.com     declined              125.0
# 17           2224037207@bb.com     captured              125.0

# %% [markdown]
# ## 4. Visualizations

# %%
# Create comprehensive visualizations
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('Transaction Data Analysis', fontsize=16)

# 1. Amount distribution
axes[0, 0].hist(df['order_total_spent'], bins=50, alpha=0.7, edgecolor='black')
axes[0, 0].set_title('Transaction Amount Distribution')
axes[0, 0].set_xlabel('Amount ($)')
axes[0, 0].set_ylabel('Frequency')

# 2. Order status distribution
status_counts = df['order_status'].value_counts()
axes[0, 1].pie(status_counts.values, labels=status_counts.index, autopct='%1.1f%%')
axes[0, 1].set_title('Order Status Distribution')

# 3. Hourly transaction pattern
hourly_counts = df['hour'].value_counts().sort_index()
axes[0, 2].bar(hourly_counts.index, hourly_counts.values)
axes[0, 2].set_title('Transactions by Hour')
axes[0, 2].set_xlabel('Hour of Day')
axes[0, 2].set_ylabel('Number of Transactions')

# 4. Amount vs Status
df.boxplot(column='order_total_spent', by='order_status', ax=axes[1, 0])
axes[1, 0].set_title('Amount Distribution by Status')
axes[1, 0].set_xlabel('Order Status')
axes[1, 0].set_ylabel('Amount ($)')

# 5. IP frequency (top 20)
ip_counts = df['browser_ip'].value_counts().head(20)
axes[1, 1].barh(range(len(ip_counts)), ip_counts.values)
axes[1, 1].set_yticks(range(len(ip_counts)))
axes[1, 1].set_yticklabels(ip_counts.index, fontsize=8)
axes[1, 1].set_title('Top 20 IPs by Transaction Count')
axes[1, 1].set_xlabel('Number of Transactions')

# 6. Email frequency (top 20)
email_counts = df['email'].value_counts().head(20)
axes[1, 2].barh(range(len(email_counts)), email_counts.values)
axes[1, 2].set_yticks(range(len(email_counts)))
axes[1, 2].set_yticklabels(email_counts.index, fontsize=8)
axes[1, 2].set_title('Top 20 Emails by Transaction Count')
axes[1, 2].set_xlabel('Number of Transactions')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Analyze Current CTG Approach

# %%
print("Current CTG (Customer Transaction Graph) Approach:")
print("=" * 50)
print("1. Converts categorical features to integers")
print("2. Creates similarity matrix between transactions")
print("3. Uses top 0.1% most similar transactions to build graph")
print("4. Analyzes graph for hubs and communities using PageRank")

print("\nFeatures used for similarity:")
selected_features = [
    'order_total_spent', 'browser_ip', 'email', 'shipping_zip',
    'normalized_full_shipping_name', 'order_captured_at', 
    'shipping_address1', 'order_status'
]
print(selected_features)

print("\nStrengths:")
print("- Uses multiple features for similarity")
print("- Graph-based analysis can find complex patterns")
print("- PageRank can identify important/hub transactions")

print("\nLimitations:")
print("- Only uses top 0.1% similarity (might miss subtle patterns)")
print("- No explicit anomaly scoring")
print("- No consideration of temporal patterns")
print("- No handling of missing values")
print("- No feature engineering for anomaly detection")
# Out:
# Current CTG (Customer Transaction Graph) Approach:
# ==================================================
# 1. Converts categorical features to integers
# 2. Creates similarity matrix between transactions
# 3. Uses top 0.1% most similar transactions to build graph
# 4. Analyzes graph for hubs and communities using PageRank
#
# Features used for similarity:
# ['order_total_spent', 'browser_ip', 'email', 'shipping_zip', 'normalized_full_shipping_name', 'order_captured_at', 'shipping_address1', 'order_status']
#
# Strengths:
# - Uses multiple features for similarity
# - Graph-based analysis can find complex patterns
# - PageRank can identify important/hub transactions
#
# Limitations:
# - Only uses top 0.1% similarity (might miss subtle patterns)
# - No explicit anomaly scoring
# - No consideration of temporal patterns
# - No handling of missing values
# - No feature engineering for anomaly detection

# %% [markdown]
# ## 6. Recommendations for Improvement

# %%
print("RECOMMENDATIONS FOR IMPROVEMENT")
print("=" * 50)

print("\n1. FEATURE ENGINEERING:")
print("   - Create time-based features (hour, day of week, time since last transaction)")
print("   - Add email pattern features (length, special chars, domain)")
print("   - Create geographic features (IP geolocation, distance between IP and shipping)")
print("   - Add behavioral features (transaction frequency, amount patterns)")

print("\n2. ANOMALY DETECTION METHODS:")
print("   - Isolation Forest for unsupervised anomaly detection")
print("   - Local Outlier Factor (LOF) for density-based anomalies")
print("   - One-Class SVM for complex pattern detection")
print("   - Statistical methods (Z-score, IQR) for simple anomalies")

print("\n3. GRAPH-BASED IMPROVEMENTS:")
print("   - Use different similarity thresholds (not just top 0.1%)")
print("   - Add edge weights based on feature importance")
print("   - Use community detection algorithms")
print("   - Implement graph neural networks")

print("\n4. ENSEMBLE APPROACH:")
print("   - Combine multiple anomaly detection methods")
print("   - Use voting or weighted scoring")
print("   - Implement different thresholds for different anomaly types")

print("\n5. EVALUATION:")
print("   - Create labeled test set with known anomalies")
print("   - Use precision, recall, F1-score for evaluation")
print("   - Implement cross-validation")
print("   - Create confusion matrix for different anomaly types")
# Out:
# RECOMMENDATIONS FOR IMPROVEMENT
# ==================================================
#
# 1. FEATURE ENGINEERING:
#    - Create time-based features (hour, day of week, time since last transaction)
#    - Add email pattern features (length, special chars, domain)
#    - Create geographic features (IP geolocation, distance between IP and shipping)
#    - Add behavioral features (transaction frequency, amount patterns)
#
# 2. ANOMALY DETECTION METHODS:
#    - Isolation Forest for unsupervised anomaly detection
#    - Local Outlier Factor (LOF) for density-based anomalies
#    - One-Class SVM for complex pattern detection
#    - Statistical methods (Z-score, IQR) for simple anomalies
#
# 3. GRAPH-BASED IMPROVEMENTS:
#    - Use different similarity thresholds (not just top 0.1%)
#    - Add edge weights based on feature importance
#    - Use community detection algorithms
#    - Implement graph neural networks
#
# 4. ENSEMBLE APPROACH:
#    - Combine multiple anomaly detection methods
#    - Use voting or weighted scoring
#    - Implement different thresholds for different anomaly types
#
# 5. EVALUATION:
#    - Create labeled test set with known anomalies
#    - Use precision, recall, F1-score for evaluation
#    - Implement cross-validation
#    - Create confusion matrix for different anomaly types

# %% [markdown]
# ## 7. Next Steps

# %%
print("NEXT STEPS:")
print("=" * 20)
print("1. Review the generated visualizations")
print("2. Implement recommended improvements")
print("3. Test different anomaly detection methods")
print("4. Evaluate performance on test data")
print("5. Create a comprehensive anomaly detection pipeline")
print("6. Document findings and recommendations")
# Out:
# NEXT STEPS:
# ====================
# 1. Review the generated visualizations
# 2. Implement recommended improvements
# 3. Test different anomaly detection methods
# 4. Evaluate performance on test data
# 5. Create a comprehensive anomaly detection pipeline
# 6. Document findings and recommendations
